# %%
# S3 Bucket Connection

import boto
import boto.s3.connection

access_key = 'AKIA34C2RRHTKN6AXXV3'
secret_key = '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'

conn = boto.connect_s3(
        aws_access_key_id = 'AKIA34C2RRHTKN6AXXV3',
        aws_secret_access_key = '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')

# %%
# Loading csv file in S3

from io import StringIO
import boto3
import pandas as pd

companies = ["GOOG", "AAPL", "AMZN", "INTC", "META", "NVDA", "AMD"]

for ticker in companies:
    url = "https://query1.finance.yahoo.com/v7/finance/download/{company}?period1=1480809600&period2=1638576000&interval=1d&events=history&includeAdjustedClose=true".format(company = ticker)
    hc = pd.read_csv(url)
    
    s3 = boto3.client('s3', aws_access_key_id = 'AKIA34C2RRHTKN6AXXV3',
                     aws_secret_access_key = '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')
    csv_buf = StringIO()
    hc.to_csv(csv_buf, header=True, index=False)
    csv_buf.seek(0)
    s3.put_object(Bucket='redrevoraisebucket', Body=csv_buf.getvalue(), Key='{company}.csv'.format(company = ticker))
